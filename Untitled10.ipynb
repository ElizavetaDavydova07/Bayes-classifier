# %%
from typing import List
from collections import defaultdict

import numpy as np

SPAM_CLASS = 'spam'
NOT_SPAM_CLASS = 'ham'

# %%
"""имплементация наивного байесовского классификатора"""
class NaiveBayes:
    def __init__(self):
        
        self.labels = [NOT_SPAM_CLASS, SPAM_CLASS]
        self.class_labels_proba = None  # априорная вероятность класса, словарь
        self.prior_word_proba = None  # частоты фичей (токенов)
    
    
    def _set_labels_prior_proba(self, target: list, data: list) -> None:
        """Вычисление априорной вероятности классов
        
        Вызов функции должен инициализировать массив self.class_labels_proba
        
        """
        class_labels_proba = dict.fromkeys(self.labels, 0.0)
        class_labels_freq = dict.fromkeys(self.labels, 0)
        num_data = len(data)
        
        for label in target:
            class_labels_proba[label] += 1
            class_labels_freq[label] +=1
            
        for label in class_labels_proba:
            class_labels_proba[label] /= num_data
            
        self.class_labels_proba = class_labels_proba
        self.class_labels_freq = class_labels_freq
        
        
    def _set_word_prior_proba(self, target, data):
        """Вычисляем априорную вероятность токенов в классе
        
        Заполняем словарь self.prior_word_proba[label][token]
        
        """
        word_proba_dict_by_class = dict.fromkeys(self.labels)
        
        for label in self.labels:
            word_proba_dict_by_class[label] = defaultdict(lambda:0)
        
        for label, tokens in zip(target, data):
            for token in tokens:
                word_proba_dict_by_class[label][token] += 1
                
        for label, tokens in word_proba_dict_by_class.items():
            for token in tokens:
                word_proba_dict_by_class[label][token] /= self.class_labels_freq [label]
                
        self.prior_word_proba = word_proba_dict_by_class
        
        
    def _tokenize_text(self, text) -> list:
        """Функция, которая разобьёт входной текст на токены
        
        Токены вернуть в виде списка"""
        
        tokens = []
        text_no_punctuation = ''.join([
            char
            for char in text
            if char not in string.punctuation
        ])
        text_lowercase = ' '.join([
            word.lower()
            for word in text_no_punctuation.split(sep=' ')
        ])
        
        tokens = text_lowercase.split(' ')
        return tokens
    
    def fit(self, target: list, data: list):
        """Обучение статистик по датасету

        :param data: массив документов, каждый документ - объект типа str
        :param target: массив меток объектов
        :return:
        """
        if not isinstance(data, list):
            raise ValueError('Аргумент data должен иметь тип list')
        if not isinstance(target, list):
            raise ValueError('Аргумент target должен иметь тип list')
        print('Данные инициализированы!')
        self._set_labels_prior_proba(target, data)
        print(f'Априорные вероятности классов {self.class_labels_proba}')
        self._set_word_prior_proba(target, data)
        print(f'Обучили априорные вероятности слов {self.prior_word_proba}') 
        
    def _predict_proba(self, data: list) -> List[tuple]:
        """Предсказываем класс для текстовой смс

        :param data: массив документов, для каждого из которых нужно предсказать метку
        :return: вероятности для каждого из классов
        """
        prediction = []
        for obj in data:
            posterior_class_proba = defaultdict(lambda: 1)
            for token in self._tokenize_text(obj):
                for label in self.labels:
                    posterior_class_proba[label] *= self.prior_word_proba[label][token]
            # сохраняем для каждой метки класса - сколько меток, таков и размер uple
            prediction.append(
                tuple(
                    posterior_class_proba[label] for label in self.labels
                )
            )
        print(f'proba: {prediction}')
        return prediction
    
    def predict(self, data) -> List[str]:
        predict_labels = []
        for proba in self._predict_proba(data):
            predict_labels.append(self.labels[np.argmax(proba)])
        return predict_labels

# %% [markdown]
# Подготвим данные для обучения классификатора

# %%
import pandas as pd

filename = 'C:/Users/Лиза/Downloads/sms_spam_collection.tar.gz'

df = pd.read_csv(
    filename,
    compression='gzip',
    header=1,
    sep='\t',
    encoding='utf8',
    names=['class', 'sms_text'],
    error_bad_lines=False
)


df.head(3)
# Out:
#   class                                           sms_text
# 0  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 1   ham  U dun say so early hor... U c already then say...
# 2   ham  Nah I don't think he goes to usf, he lives aro...

# %%
num_objects, num_features = df.shape
print(num_objects, num_features)
# Out:
# 5571 2

# %% [markdown]
# Если есть, удалим объекты Nan

# %%
df = df.dropna()

# %% [markdown]
# Очистим данные

# %%
import string

def text_preprocess(sms_text: str) -> str:
    """Преобразование текста для анализа"""
    text_no_punctuation = ''.join([
        char
        for char in sms_text
        if char not in string.punctuation
    ])
    text_lowercase = ' '.join([
        word.lower()
        for word in text_no_punctuation.split(sep=' ')
    ])
    
    return text_lowercase

def tokenize_text(text: str):
    tokens = []
    processed_text = text_preprocess(text)
    tokens = text.split(' ')
    return tokens

# %%
all_text = df['sms_text'].tolist()
data = []

# %%
for s in all_text:
    data.append(tokenize_text(s))

# %%
targets = df['class'].tolist()

# %%
naive_bayes = NaiveBayes()

# %%
naive_bayes.fit(targets, data)
# Out:
# Данные инициализированы!
# Априорные вероятности классов {'ham': 0.8658886894075404, 'spam': 0.1341113105924596}
# Обучили априорные вероятности слов {'ham': defaultdict(<function NaiveBayes._set_word_prior_proba.<locals>.<lambda> at 0x0000027FA14DC940>, {'U': 0.047688160895708064, 'dun': 0.009537632179141614, 'say': 0.014928467758656437, 'so': 0.05660377358490566, 'early': 0.004976155919552146, 'hor...': 0.00041467965996267884, 'c': 0.008500933029234915, 'already': 0.009122952519178934, 'then': 0.02861289653742484, 'say...': 0.0006220194899440182, 'Nah': 0.001451378809869376, 'I': 0.29836201534314744, "don't": 0.02197802197802198, 'think': 0.023222060957910014, 'he': 0.026332158407630105, 'goes': 0.005390835579514825, 'to': 0.3188886585113, 'usf,': 0.00041467965996267884, 'lives': 0.00041467965996267884, 'around': 0.01057433132904831, 'here': 0.0147211279286751, 'though': 0.003110097449720091, 'Even': 0.003110097449720091, 'my': 0.12875803441841177, 'brother': 0.0018660584698320546, 'is': 0.1337341903379639, 'not': 0.06717810491395397, 'like': 0.04374870412606262, 'speak': 0.0022807381297947336, 'with': 0.05183495749533485, 'me.': 0.018660584698320548, 'They': 0.006220194899440182, 'treat': 0.0022807381297947336, 'me': 0.11217084801990462, 'aids': 0.00020733982998133942, 'patent.': 0.00020733982998133942, 'As': 0.005598175409496164, 'per': 0.0022807381297947336, 'your': 0.07754509641302094, 'request': 0.0012440389798880364, "'Melle": 0.0006220194899440182, 'Melle': 0.0006220194899440182, '(Oru': 0.0006220194899440182, 'Minnaminunginte': 0.0006220194899440182, 'Nurungu': 0.0006220194899440182, "Vettam)'": 0.0006220194899440182, 'has': 0.017209205888451172, 'been': 0.016172506738544475, 'set': 0.0037321169396641093, 'as': 0.023222060957910014, 'callertune': 0.0010366991499066972, 'for': 0.09973045822102426, 'all': 0.04001658718639851, 'Callers.': 0.0010366991499066972, 'Press': 0.0010366991499066972, '*9': 0.0010366991499066972, 'copy': 0.0018660584698320546, 'friends': 0.005805515239477504, 'Callertune': 0.0010366991499066972, "I'm": 0.057640472734812355, 'gonna': 0.011818370308936347, 'be': 0.06531204644412192, 'home': 0.02197802197802198, 'soon': 0.005805515239477504, 'and': 0.15322413435620982, 'i': 0.15384615384615385, 'want': 0.0294422558573502, 'talk': 0.006427534729421522, 'about': 0.029649595687331536, 'this': 0.03669914990669708, 'stuff': 0.0066348745594028615, 'anymore': 0.00041467965996267884, 'tonight,': 0.0006220194899440182, 'k?': 0.00041467965996267884, "I've": 0.008293593199253577, 'cried': 0.00020733982998133942, 'enough': 0.0043541364296081275, 'today.': 0.005183495749533485, 'searching': 0.0010366991499066972, 'the': 0.21335268505079827, 'right': 0.012025710138917687, 'words': 0.002902757619738752, 'thank': 0.0018660584698320546, 'you': 0.30313083143271824, 'breather.': 0.00020733982998133942, 'promise': 0.001451378809869376, 'wont': 0.006427534729421522, 'take': 0.01824590503835787, 'help': 0.005183495749533485, 'granted': 0.00020733982998133942, 'will': 0.06095791001451379, 'fulfil': 0.00020733982998133942, 'promise.': 0.00041467965996267884, 'You': 0.03856520837652913, 'have': 0.07236160066348746, 'wonderful': 0.002902757619738752, 'a': 0.2025710138917686, 'blessing': 0.00041467965996267884, 'at': 0.06925150321376737, 'times.': 0.0008293593199253577, 'HAVE': 0.0018660584698320546, 'A': 0.016794526228488493, 'DATE': 0.00020733982998133942, 'ON': 0.002488077959776073, 'SUNDAY': 0.00020733982998133942, 'WITH': 0.0026954177897574125, 'WILL!!': 0.00020733982998133942, 'Oh': 0.012440389798880364, "k...i'm": 0.00020733982998133942, 'watching': 0.004561476259589467, 'here:)': 0.00041467965996267884, 'Eh': 0.0012440389798880364, 'u': 0.1347708894878706, 'remember': 0.004768816089570807, 'how': 0.022600041467965997, '2': 0.05971387103462575, 'spell': 0.0006220194899440182, 'his': 0.01057433132904831, 'name...': 0.00020733982998133942, 'Yes': 0.0074642338793282186, 'did.': 0.00041467965996267884, 'He': 0.01098901098901099, 'v': 0.005390835579514825, 'naughty': 0.0010366991499066972, 'make': 0.016379846568525813, 'until': 0.00414 ...

# %%
naive_bayes.prior_word_proba['ham']['thank'], naive_bayes.prior_word_proba['spam']['thank']
# Out:
# (0.0018660584698320546, 0)

# %% [markdown]
# Предсказание метки класса

# %%
import numpy as np
# рандомный объект датасета

random_obj_ind = np.random.randint(low=0, high=num_objects, size=3)
random_obj_list = df['sms_text'].values[random_obj_ind].tolist()
random_target = df['class'][random_obj_ind].tolist()

print(random_obj_list)
naive_bayes.predict(
    random_obj_list
)
# Out:
# ['Am okay. Will soon be over. All the best', 'So is there anything specific I should be doing with regards to jaklin or what because idk what the fuck', 'Hello! Just got here, st andrews-boy its a long way! Its cold. I will keep you posted']
# proba: [(1.4018403095926958e-16, 0.0), (1.3793106986974235e-37, 0.0), (0.0, 0.0)]
# ['ham', 'ham', 'ham']
